# %% [markdown]
# <h1>Quantitative Momentum Strategy</h1>

# %% [markdown]
# "Momentum investing" means investing in the stocks that increased in price the most.
#
# For this project. I will be building an investing strategy that returns the 50 stocks with the

# %% [markdown]
# <h3>Importing Libraries</h3>

# %%
import numpy as np
import pandas as pd
import requests
import math
import xlsxwriter
from scipy.stats import percentileofscore as score

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h3>Importing List of Stocks</h3>

# %%
stocks = pd.read_csv("sp_500_stocks.csv")
from secret_keys import IEX_CLOUD_API_TOKEN

# %% [markdown]
# <h3>Creating a Data Frame to store our data</h3>

# %%
columns = [
    "Ticker",
    "Stock Price",
    "One-Year Price Return",
    "One-Year Return Percentile",
    "Six-Month Price Return",
    "Six-Month Return Percentile",
    "Three-Month Price Return",
    "Three-Month Return Percentile",
    "One-Month Price Return",
    "One-Month Return Percentile",
    "HQM Score",
    "Number of Shares to Buy"
]
df = pd.DataFrame(columns=columns)

# %% [markdown]
# <h3>Accessing the IEX Cloud API</h3>

# %% [markdown]
# The IEX Cloud API allows a batch request of 100 Tickers at a time. We need to split our list into multiple lists of 100 Tickers (or less). Here is a helper function that does this:

# %%
'''
Function that splits a list (l) into multiple lists of (n) items
args:
    l: array
    n: number
returns 2D array
'''
def split_list(l, n):
    for i in range(0, len(l), n):
        yield l[i:i+n]

# %%
# Split our symbol list into multiple list of 100 symbols
symbols = stocks["Ticker"]
symbol_lists = list(split_list(symbols, 100))

# %% [markdown]
# In order to execute a batch request with the IEX Cloud API, we need to enter the stocks in the URL separated by a comma.<br>
#
# <b>Example</b>: [AAL, AAPL, ABBV] becomes "AAL,AAPL,AABBV"

# %%
symbol_batches = [] # the array that contains the symbols separated by commas
for symbol_list in symbol_lists:
    symbol_batches.append(",".join(symbol_list))

# %% [markdown]
# Get the key to access the API

# %%
from secret_keys import IEX_CLOUD_API_TOKEN

# %% [markdown]
# Do batch requests

# %%
for symbol_batch in symbol_batches:
    # Build URL request
    url = f"https://sandbox.iexapis.com/stable/stock/market/batch?symbols={symbol_batch}&types=stats,price&token={IEX_CLOUD_API_TOKEN}"
    # Fetch data
    data = requests.get(url).json()
    # Extract the symbols from the batch
    for symbol in symbol_batch.split(","):
        if symbol in data:
            symbol_data = data[symbol]
            symbol_stats = symbol_data["stats"]
            # Avoid getting None values
            for key in ["year1ChangePercent", "month6ChangePercent", "month3ChangePercent", "month1ChangePercent"]:
                if symbol_stats[key] == None:
                    symbol_stats[key] = 0
            # Percentiles are temporarily filled with N/A as they are calculated later in the script
            df = df.append(pd.Series([
                symbol,
                symbol_data["price"],
                symbol_stats["year1ChangePercent"],
                "N/A",
                symbol_stats["month6ChangePercent"],
                "N/A",
                symbol_stats["month3ChangePercent"],
                "N/A",
                symbol_stats["month1ChangePercent"],
                "N/A",
                "N/A",
                "N/A"
            ], index=columns), ignore_index=True)

# %%
df
# Out:
#     Ticker  Stock Price  One-Year Price Return One-Year Return Percentile  \
# 0        A       123.63              -0.178825                        N/A
# 1      AAL        14.50              -0.390607                        N/A
# 2      AAP       184.30              -0.084312                        N/A
# 3     AAPL       144.45               0.071684                        N/A
# 4     ABBV       156.34               0.416861                        N/A
# ..     ...          ...                    ...                        ...
# 496    YUM       119.43              -0.007427                        N/A
# 497    ZBH       110.64              -0.344828                        N/A
# 498   ZBRA       321.54              -0.413110                        N/A
# 499   ZION        54.16              -0.039670                        N/A
# 500    ZTS       177.78              -0.062581                        N/A
#
#      Six-Month Price Return Six-Month Return Percentile  \
# 0                 -0.232805                         N/A
# 1                 -0.243427                         N/A
# 2                 -0.198764                         N/A
# 3                 -0.200184                         N/A
# 4                  0.168251                         N/A
# ..                      ...                         ...
# 496               -0.147419                         N/A
# 497               -0.143404                         N/A
# 498               -0.488476                         N/A
# 499               -0.147115                         N/A
# 500               -0.283581                         N/A
#
#      Three-Month Price Return Three-Month Return Percentile  \
# 0                   -0.108825                           N/A
# 1                   -0.191446                           N/A
# 2                   -0.145178                           N/A
# 3                   -0.193092                           N/A
# 4                   -0.047734                           N/A
# ..                        ...                           ...
# 496                 -0.039328                           N/A
# 497                 -0.132037                           N/A
# 498                 -0.285958                           N/A
# 499                 -0.262068                           N/A
# 500                 -0.078473                           N/A
#
#      One-Month Price Return One-Month Return Percentile HQM Score  \
# 0                  0.007845                         N/A       N/A
# 1                 -0.140751                         N/A       N/A
# 2                 -0.003257                         N/A       N/A
# 3                  0.008414                         N/A       N/A
# 4                  0.002619                         N/A       N/A
# ..                      ...                         ...       ...
# 496               -0.005241                         N/A       N/A
# 497               -0.088409                         N/A       N/A
# 498               -0.043516                         N/A       N/A
# 499               -0.029928                         N/A       N/A
# 500                0.073269                         N/A       N/A
#
#     Number of Shares to Buy
# 0                       N/A
# 1                       N/A
# 2                       N/A
# 3                       N/A
# 4                       N/A
# ..                      ...
# 496                     N/A
# 497                     N/A
# 498                     N/A
# 499                     N/A
# 500                     N/A
#
# [501 rows x 12 columns]

# %% [markdown]
# <h3>Calculate the Percentile of the Time Periods</h3>

# %%
time_periods = ["One-Year", "Six-Month", "Three-Month", "One-Month"]

for row in df.index:
    for time_period in time_periods:
        percentile_col = f"{time_period} Return Percentile"
        change_col = f"{time_period} Price Return"
        df.loc[row, percentile_col] = score(
            df[change_col],
            df.loc[row, change_col]
        ) / 100

df
# Out:
#     Ticker  Stock Price  One-Year Price Return One-Year Return Percentile  \
# 0        A       123.63              -0.178825                   0.299401
# 1      AAL        14.50              -0.390607                    0.06986
# 2      AAP       184.30              -0.084312                   0.497006
# 3     AAPL       144.45               0.071684                   0.744511
# 4     ABBV       156.34               0.416861                   0.962076
# ..     ...          ...                    ...                        ...
# 496    YUM       119.43              -0.007427                   0.596806
# 497    ZBH       110.64              -0.344828                   0.107784
# 498   ZBRA       321.54              -0.413110                   0.055888
# 499   ZION        54.16              -0.039670                   0.552894
# 500    ZTS       177.78              -0.062581                   0.528942
#
#      Six-Month Price Return Six-Month Return Percentile  \
# 0                 -0.232805                    0.307385
# 1                 -0.243427                    0.277445
# 2                 -0.198764                    0.387226
# 3                 -0.200184                    0.379242
# 4                  0.168251                    0.918164
# ..                      ...                         ...
# 496               -0.147419                     0.47505
# 497               -0.143404                    0.487026
# 498               -0.488476                    0.015968
# 499               -0.147115                    0.477046
# 500               -0.283581                    0.195609
#
#      Three-Month Price Return Three-Month Return Percentile  \
# 0                   -0.108825                      0.528942
# 1                   -0.191446                      0.259481
# 2                   -0.145178                      0.413174
# 3                   -0.193092                      0.255489
# 4                   -0.047734                      0.716567
# ..                        ...                           ...
# 496                 -0.039328                      0.744511
# 497                 -0.132037                      0.449102
# 498                 -0.285958                      0.081836
# 499                 -0.262068                      0.113772
# 500                 -0.078473                      0.632735
#
#      One-Month Price Return One-Month Return Percentile HQM Score  \
# 0                  0.007845                    0.750499       N/A
# 1                 -0.140751                    0.087824       N/A
# 2                 -0.003257                    0.660679       N/A
# 3                  0.008414                    0.758483       N/A
# 4                  0.002619                    0.720559       N/A
# ..                      ...                         ...       ...
# 496               -0.005241                    0.652695       N/A
# 497               -0.088409                    0.209581       N/A
# 498               -0.043516                    0.449102       N/A
# 499               -0.029928                    0.536926       N/A
# 500                0.073269                     0.93014       N/A
#
#     Number of Shares to Buy
# 0                       N/A
# 1                       N/A
# 2                       N/A
# 3                       N/A
# 4                       N/A
# ..                      ...
# 496                     N/A
# 497                     N/A
# 498                     N/A
# 499                     N/A
# 500                     N/A
#
# [501 rows x 12 columns]

# %% [markdown]
# <h3>Calculate the HQM Score for each Stock</h3>
#
# We can judge a Stock by its <b>Quality Momentum</b> - if the momentum of the stock is stable over time or if the value increases at once. High Quality Momentum Stocks increase steadily over time while Lower Quality Stocks experience unstable changes.
#
# The HQM Score (High Quality Momentum Score) takes the mean of the Return Percentiles over a certain period of time and is calculated as a percentage (100% being a high score and 0% being a low score)

# %%
from statistics import mean

for row in df.index:
    momentum_percentiles = []
    for time_period in time_periods:
        momentum_percentiles.append(df.loc[row, f"{time_period} Return Percentile"])
    df.loc[row, "HQM Score"] = mean(momentum_percentiles)

df
# Out:
#     Ticker  Stock Price  One-Year Price Return One-Year Return Percentile  \
# 0        A       123.63              -0.178825                   0.299401
# 1      AAL        14.50              -0.390607                    0.06986
# 2      AAP       184.30              -0.084312                   0.497006
# 3     AAPL       144.45               0.071684                   0.744511
# 4     ABBV       156.34               0.416861                   0.962076
# ..     ...          ...                    ...                        ...
# 496    YUM       119.43              -0.007427                   0.596806
# 497    ZBH       110.64              -0.344828                   0.107784
# 498   ZBRA       321.54              -0.413110                   0.055888
# 499   ZION        54.16              -0.039670                   0.552894
# 500    ZTS       177.78              -0.062581                   0.528942
#
#      Six-Month Price Return Six-Month Return Percentile  \
# 0                 -0.232805                    0.307385
# 1                 -0.243427                    0.277445
# 2                 -0.198764                    0.387226
# 3                 -0.200184                    0.379242
# 4                  0.168251                    0.918164
# ..                      ...                         ...
# 496               -0.147419                     0.47505
# 497               -0.143404                    0.487026
# 498               -0.488476                    0.015968
# 499               -0.147115                    0.477046
# 500               -0.283581                    0.195609
#
#      Three-Month Price Return Three-Month Return Percentile  \
# 0                   -0.108825                      0.528942
# 1                   -0.191446                      0.259481
# 2                   -0.145178                      0.413174
# 3                   -0.193092                      0.255489
# 4                   -0.047734                      0.716567
# ..                        ...                           ...
# 496                 -0.039328                      0.744511
# 497                 -0.132037                      0.449102
# 498                 -0.285958                      0.081836
# 499                 -0.262068                      0.113772
# 500                 -0.078473                      0.632735
#
#      One-Month Price Return One-Month Return Percentile HQM Score  \
# 0                  0.007845                    0.750499  0.471557
# 1                 -0.140751                    0.087824  0.173653
# 2                 -0.003257                    0.660679  0.489521
# 3                  0.008414                    0.758483  0.534431
# 4                  0.002619                    0.720559  0.829341
# ..                      ...                         ...       ...
# 496               -0.005241                    0.652695  0.617265
# 497               -0.088409                    0.209581  0.313373
# 498               -0.043516                    0.449102  0.150699
# 499               -0.029928                    0.536926   0.42016
# 500                0.073269                     0.93014  0.571856
#
#     Number of Shares to Buy
# 0                       N/A
# 1                       N/A
# 2                       N/A
# 3                       N/A
# 4                       N/A
# ..                      ...
# 496                     N/A
# 497                     N/A
# 498                     N/A
# 499                     N/A
# 500                     N/A
#
# [501 rows x 12 columns]

# %% [markdown]
# <h3>Selecting the 50 Best Momentum Stocks</h3>

# %%
# Sort the values of the Data Frame
df.sort_values("HQM Score", ascending=False, inplace=True)

# Extract the 50 first elements of the sorted Data Frame
df = df[:50]

# Reset the indices
df.reset_index(inplace=True, drop=True)

df
# Out:
#    Ticker  Stock Price  One-Year Price Return One-Year Return Percentile  \
# 0      LB        80.39               2.315578                        1.0
# 1    VRTX       298.33               0.507345                   0.974052
# 2     COG        22.91               0.354857                     0.9501
# 3     LLY       332.09               0.446025                   0.968064
# 4     HRB        35.11               0.529179                   0.978044
# 5    DLTR       158.68               0.608165                   0.988024
# 6      DG       253.20               0.184779                   0.882236
# 7     AZO      2161.04               0.470192                    0.97006
# 8     HSY       231.77               0.265064                   0.932136
# 9     BMY        81.99               0.222070                   0.906188
# 10    SYY        89.27               0.140737                   0.844311
# 11    MRK        93.70               0.261001                    0.93014
# 12   ULTA       411.86               0.179008                   0.874251
# 13    GIS        73.44               0.215569                   0.896208
# 14      K        74.04               0.141169                   0.846307
# 15    HII       223.03               0.035738                   0.700599
# 16    WRB        68.45               0.395179                   0.958084
# 17     CI       271.22               0.139847                   0.842315
# 18    TAP        58.53               0.042948                   0.712575
# 19    CPB        49.20               0.096795                   0.784431
# 20    PWR       131.19               0.383736                   0.956088
# 21    UNM        34.44               0.224708                   0.908184
# 22    NOC       481.40               0.258772                   0.928144
# 23    IBM       142.56               0.015776                   0.660679
# 24    JNJ       185.88               0.144366                   0.848303
# 25    DRE        57.48               0.226843                   0.914172
# 26    GPC       138.76               0.102798                   0.794411
# 27   MNST        99.27               0.027489                   0.682635
# 28    VAR       180.05               0.581810                   0.984032
# 29    MCK       322.05               0.716744                   0.994012
# 30     LW        75.00              -0.096312                   0.467066
# 31    PGR       118.19               0.219288                     0.9002
# 32   ABBV       156.34               0.416861                   0.962076
# 33    AJG       169.76               0.185410                   0.884232
# 34   TMUS       142.55              -0.057106                   0.540918
# 35     KO        65.80               0.203291                   0.892216
# 36    KMB       136.24               0.046148                   0.720559
# 37    STZ       248.90               0.089447                   0.774451
# 38     RE       291.47               0.134898                   0.838323
# 39    HUM       466.22               0.041310                   0.708583
# 40    CAG        35.50              -0.007925                    0.59481
# 41    TIF       133.89               0.003015                   0.644711
# 42     CL        83.51               0.009754                   0.648703
# 43     GL       101.31               0.020309                   0.668663
# 44   PRGO        42.58              -0.100317                   0.457086
# 45    MCD       253.60               0.092388                   0.778443
# 46     GD       229.27               0.199066                    0.89022
# 47    MMC       159.62               0.156715                   0.860279
# 0                      N/A
# 1                      N/A
# 2                      N/A
# 3                      N/A
# 4                      N/A
# 5                      N/A
# 6                      N/A
# 7                      N/A
# 8                      N/A
# 9                      N/A
# 10                     N/A
# 11                     N/A
# 12                     N/A
# 13                     N/A
# 14                     N/A
# 15                     N/A
# 16                     N/A
# 17                     N/A
# 18                     N/A
# 19                     N/A
# 20                     N/A
# 21                     N/A
# 22                     N/A
# 23                     N/A
# 24                     N/A
# 25                     N/A
# 26                     N/A
# 27                     N/A
# 28                     N/A
# 29                     N/A
# 30                     N/A
# 31                     N/A
# 32                     N/A
# 33                     N/A
# 34                     N/A
# 35                     N/A
# 36                     N/A
# 37                     N/A
# 38                     N/A
# 39                     N/A
# 40                     N/A
# 41                     N/A
# 42                     N/A
# 43                     N/A
# 44                     N/A
# 45                     N/A
# 46                     N/A
# 47                     N/A
# 48                     N/A
# 49                     N/A

# %% [markdown]
# <h3>Calculating the number of shares to buy</h3>

# %% [markdown]
# Get the user's portfolio size by prompting an input box

# %%
def get_portfolio_size():
    portfolio_size = input("Enter the value of your portfolio: ")
    
    try:
        val = float(portfolio_size)
    except ValueError:
        print("\nYou need to enter a number.")
        val = get_portfolio_size()
    
    return val

# %%
portfolio_size = get_portfolio_size()
# Out:
# Enter the value of your portfolio: 1000000

# %%
position_size = portfolio_size / len(df.index)

for row in df.index:
    df.loc[row, "Number of Shares to Buy"] = position_size // df.loc[row, "Stock Price"]

df
# Out:
#    Ticker  Stock Price  One-Year Price Return One-Year Return Percentile  \
# 0      LB        80.39               2.315578                        1.0
# 1    VRTX       298.33               0.507345                   0.974052
# 2     COG        22.91               0.354857                     0.9501
# 3     LLY       332.09               0.446025                   0.968064
# 4     HRB        35.11               0.529179                   0.978044
# 5    DLTR       158.68               0.608165                   0.988024
# 6      DG       253.20               0.184779                   0.882236
# 7     AZO      2161.04               0.470192                    0.97006
# 8     HSY       231.77               0.265064                   0.932136
# 9     BMY        81.99               0.222070                   0.906188
# 10    SYY        89.27               0.140737                   0.844311
# 11    MRK        93.70               0.261001                    0.93014
# 12   ULTA       411.86               0.179008                   0.874251
# 13    GIS        73.44               0.215569                   0.896208
# 14      K        74.04               0.141169                   0.846307
# 15    HII       223.03               0.035738                   0.700599
# 16    WRB        68.45               0.395179                   0.958084
# 17     CI       271.22               0.139847                   0.842315
# 18    TAP        58.53               0.042948                   0.712575
# 19    CPB        49.20               0.096795                   0.784431
# 20    PWR       131.19               0.383736                   0.956088
# 21    UNM        34.44               0.224708                   0.908184
# 22    NOC       481.40               0.258772                   0.928144
# 23    IBM       142.56               0.015776                   0.660679
# 24    JNJ       185.88               0.144366                   0.848303
# 25    DRE        57.48               0.226843                   0.914172
# 26    GPC       138.76               0.102798                   0.794411
# 27   MNST        99.27               0.027489                   0.682635
# 28    VAR       180.05               0.581810                   0.984032
# 29    MCK       322.05               0.716744                   0.994012
# 30     LW        75.00              -0.096312                   0.467066
# 31    PGR       118.19               0.219288                     0.9002
# 32   ABBV       156.34               0.416861                   0.962076
# 33    AJG       169.76               0.185410                   0.884232
# 34   TMUS       142.55              -0.057106                   0.540918
# 35     KO        65.80               0.203291                   0.892216
# 36    KMB       136.24               0.046148                   0.720559
# 37    STZ       248.90               0.089447                   0.774451
# 38     RE       291.47               0.134898                   0.838323
# 39    HUM       466.22               0.041310                   0.708583
# 40    CAG        35.50              -0.007925                    0.59481
# 41    TIF       133.89               0.003015                   0.644711
# 42     CL        83.51               0.009754                   0.648703
# 43     GL       101.31               0.020309                   0.668663
# 44   PRGO        42.58              -0.100317                   0.457086
# 45    MCD       253.60               0.092388                   0.778443
# 46     GD       229.27               0.199066                    0.89022
# 47    MMC       159.62               0.156715                   0.860279
# 48    ROL        36.72               0.044046                   0.714571
# 49   SNPS       326.37               0.183470                   0.878244
#
#     Six-Month Price Return Six-Month Return Percentile  \
# 0                 0.837057                    0.998004
# 1                 0.312637                    0.972056
# 2                 0.186396                     0.93014
# 3                 0.205775                    0.946108
# 4                 0.523769                    0.996008
# 5                 0.148068                    0.904192
# 6                 0.127071                    0.878244
# 7                 0.075173                    0.832335
# 8                 0.174847                    0.924152
# 9                 0.299900                    0.966068
# 10                0.131558                    0.888224
# 11                0.252599                     0.96008
# 12                0.047695                    0.806387
# 13                0.087045                    0.846307
# 14                0.139613                    0.898204
# 15                0.196918                    0.942116
# 16                0.291182                    0.962076
# 17                0.191371                    0.934132
# 18                0.245116                    0.956088
# 19                0.181604                    0.928144
# 20                0.130198                     0.88024
# 21                0.442518                     0.99002
# 22                0.235332                    0.954092
# 23                0.116707                    0.872255
# 24                0.098351                    0.858283
# 25               -0.072793                    0.618762
# 26                0.024710                    0.778443
# 27                0.008033                    0.766467
# 28                0.029946                    0.786427
# 29                0.342456                    0.978044
# 30                0.173788                    0.922156
# 31                0.151677                    0.908184
# 32                0.168251                    0.918164
# 33               -0.000877                    0.728543
# 34                0.147374                    0.902196
# 35                0.102550                    0.864271
# 36               -0.014808                    0.706587
# 37                0.013084                    0.770459
# 38                0.076595                    0.838323
# 39               -0.004929                    0.724551
# 40                0.042338                    0.800399
# 41                0.081467                    0.842315
# 42               -0.018718                    0.698603
# 43                0.076298                    0.836327
# 44                0.057706                    0.818363
# 45               -0.059400                    0.640719
# 46                0.099565                    0.860279
# 47               -0.065132                    0.630739
# 48                0.080250                    0.840319
# 49               -0.133101                    0.506986
#
#     Three-Month Price Return Three-Month Return Percentile  \
# 0                   0.217417                      0.992016
# 1                   0.159015                      0.986028
# 2                   0.262346                      0.994012
# 3                   0.134937                      0.984032
# 4                   0.367138                           1.0
# 5                   0.005164                      0.852295
# 6                   0.124280                      0.976048
# 7                   0.066113                       0.94012
# 8                   0.031516                      0.896208
# 9                   0.088448                      0.954092
# 10                  0.065137                      0.938124
# 11                  0.161607                      0.988024
# 12                  0.041089                      0.916168
# 13                  0.058044                      0.934132
# 14                  0.127709                      0.978044
# 15                  0.052985                      0.932136
# 16                  0.039155                      0.912176
# 17                  0.094125                       0.96008
# 18                  0.041222                      0.918164
# 19                  0.101022                      0.968064
# 20                 -0.063252                      0.676647
# 21                  0.090161                      0.956088
# 22                  0.016589                      0.874251
# 23                  0.096973                      0.964072
# 24                  0.037327                       0.91018
# 25                  0.018220                       0.88024
# 0                    248.0
# 1                     67.0
# 2                    872.0
# 3                     60.0
# 4                    569.0
# 5                    126.0
# 6                     78.0
# 7                      9.0
# 8                     86.0
# 9                    243.0
# 10                   224.0
# 11                   213.0
# 12                    48.0
# 13                   272.0
# 14                   270.0
# 15                    89.0
# 16                   292.0
# 17                    73.0
# 18                   341.0
# 19                   406.0
# 20                   152.0
# 21                   580.0
# 22                    41.0
# 23                   140.0
# 24                   107.0
# 25                   347.0
# 26                   144.0
# 27                   201.0
# 28                   111.0
# 29                    62.0
# 30                   266.0
# 31                   169.0
# 32                   127.0
# 33                   117.0
# 34                   140.0
# 35                   303.0
# 36                   146.0
# 37                    80.0
# 38                    68.0
# 39                    42.0
# 40                   563.0
# 41                   149.0
# 42                   239.0
# 43                   197.0
# 44                   469.0
# 45                    78.0
# 46                    87.0
# 47                   125.0
# 48                   544.0
# 49                    61.0

# %% [markdown]
# <h3>Export the Data Frame to an Excel File Traders can use</h3>

# %% [markdown]
# Initialize the XlsxWriter Object

# %%
writer = pd.ExcelWriter("quantitative_momentum_strategy.xlsx", engine="xlsxwriter")

# %% [markdown]
# Pass the Data Frame to the Writer Object

# %%
SHEET_NAME = "Recommended Trades"
df.to_excel(writer, SHEET_NAME, index=False)

# %% [markdown]
# Format the excel file with the following rules:
# <ul>
#     <li><b>Tickers:</b> String format</li>
#     <li><b>Stock Prices:</b> \$XX.XX</li>
#     <li><b>Percentages:</b> %X.X</li>
#     <li><b>Number of Shares to Buy:</b> Integer</li>
# </ul>

# %%
# Setup the styles
BACKGROUND_COLOR = "#0A0A23"
FONT_COLOR = "#FFFFFF"
BORDER_WIDTH = 1

STRING_FORMAT = writer.book.add_format({
    "font_color": FONT_COLOR,
    "bg_color": BACKGROUND_COLOR,
    "border": BORDER_WIDTH
})

PRICE_FORMAT = writer.book.add_format({
    "num_format": "$0.00",
    "font_color": FONT_COLOR,
    "bg_color": BACKGROUND_COLOR,
    "border": BORDER_WIDTH
})

VALUE_FORMAT = writer.book.add_format({
    "num_format": "$#,##0.00",
    "font_color": FONT_COLOR,
    "bg_color": BACKGROUND_COLOR,
    "border": BORDER_WIDTH
})

NUMBER_FORMAT = writer.book.add_format({
    "num_format": "0",
    "font_color": FONT_COLOR,
    "bg_color": BACKGROUND_COLOR,
    "border": BORDER_WIDTH
})

PERCENT_FORMAT = writer.book.add_format({
    "num_format": "0.0%",
    "font_color": FONT_COLOR,
    "bg_color": BACKGROUND_COLOR,
    "border": BORDER_WIDTH
})

map_columns_to_format = {
    "A": [columns[0], STRING_FORMAT],
    "B": [columns[1], PRICE_FORMAT],
    "C": [columns[2], PERCENT_FORMAT],
    "D": [columns[3], PERCENT_FORMAT],
    "E": [columns[4], PERCENT_FORMAT],
    "F": [columns[5], PERCENT_FORMAT],
    "G": [columns[6], PERCENT_FORMAT],
    "H": [columns[7], PERCENT_FORMAT],
    "I": [columns[8], PERCENT_FORMAT],
    "J": [columns[9], PERCENT_FORMAT],
    "K": [columns[10], PERCENT_FORMAT],
    "L": [columns[11], NUMBER_FORMAT]
}

# %%
# Format Cells
for col in map_columns_to_format:
    title, cell_format = map_columns_to_format[col]
    
    # Format Header
    writer.sheets[SHEET_NAME].write(f"{col}1", title, STRING_FORMAT)
    
    # Format Body
    writer.sheets[SHEET_NAME].set_column(f"{col}:{col}", 22, cell_format)
writer.save()

# %% [markdown]
# Save the writer to the Excel File

# %%
writer.save()
